# %% [markdown]
# # pyOpenCGA basic variant and interpretation usage
#
# ------
#
#
# **[NOTE]** The server methods used by pyopencga client are defined in the following swagger URL:
# - http://bioinfodev.hpc.cam.ac.uk/opencga-test/webservices
#
# **[NOTE]** Current implemented methods are registered at the following spreadsheet:
# - https://docs.google.com/spreadsheets/d/1QpU9yl3UTneqwRqFX_WAqCiCfZBk5eU-4E3K-WVvuoc/edit?usp=sharing

# %% [markdown]
# ## Loading pyOpenCGA

# %%
from pyopencga.opencga_config import ClientConfiguration
from pyopencga.opencga_client import OpencgaClient
from pprint import pprint
import json

# %% [markdown]
# ## Setting credentials for LogIn

# %% [markdown]
# **Credentials**
#
# Plese add the credentials for opencga login into a file in json format and read them from there.

# %%
# server host
host = 'http://bioinfo.hpc.cam.ac.uk/opencga-prod'

# user credentials
user = "demouser"
passwd = "demouser" ## you can skip this, see below.

# the user demo access projects from user opencga
prj_owner = "demo"

# %% [markdown]
# ## Creating ConfigClient for server connection configuration

# %%
# Creating ClientConfiguration dict
config_dict = {"rest": {
                       "host": host 
                    }
               }

print("Config information:\n",config_dict)
# Out:
# Config information:
#  {'rest': {'host': 'http://bioinfo.hpc.cam.ac.uk/opencga-prod'}}

# %% [markdown]
# ## Login with user credentials

# %%
config = ClientConfiguration(config_dict)
oc = OpencgaClient(config)

## Login
oc.login(user, passwd)

# %% [markdown]
# **You are now connected to OpenCGA**

# %% [markdown]
# ## Querying Variants

# %% [markdown]
# Let's get the variant client to query OpenCGA server

# %%
## Let's use corpasome study
study = 'family:corpasome'
variant_client = oc.variants
variants = variant_client.query(study=study, gene='BRCA2', limit=5)
pprint(variants.get_responses())
# Out:
# [{'attributes': {'approximateCount': False, 'source': 'solr+hadoop'},
#   'events': [],
#   'numDeleted': 0,
#   'numInserted': 0,
#   'numMatches': 26,
#   'numResults': 5,
#   'numTotalResults': 26,
#   'numUpdated': 0,
#   'result': [{'alternate': 'T',
#               'annotation': {'additionalAttributes': {'opencga': {'attribute': {'annotationId': 'CURRENT',
#                                                                                 'release': '1'}}},
#                              'alternate': 'T',
#                              'chromosome': '13',
#                              'consequenceTypes': [{'biotype': 'protein_coding',
#                                                    'ensemblGeneId': 'ENSG00000189167',
#                                                    'ensemblTranscriptId': 'ENST00000533490',
#                                                    'geneName': 'ZAR1L',
#                                                    'sequenceOntologyTerms': [{'accession': 'SO:0001627',
#                                                                               'name': 'intron_variant'}],
#                                                    'strand': '-',
#                                                    'transcriptAnnotationFlags': ['CCDS',
#                                                                                  'basic']},
#                                                   {'biotype': 'protein_coding',
#                                                    'ensemblGeneId': 'ENSG00000189167',
#                                                    'ensemblTranscriptId': 'ENST00000345108',
#                                                    'geneName': 'ZAR1L',
#                                                    'sequenceOntologyTerms': [{'accession': 'SO:0001627',
#                                                                               'name': 'intron_variant'}],
#                                                    'strand': '-',
#                                                    'transcriptAnnotationFlags': ['CCDS',
#                                                                                  'basic']},
#                                                   {'biotype': 'protein_coding',
#                                                    'ensemblGeneId': 'ENSG00000139618',
#                                                    'ensemblTranscriptId': 'ENST00000380152',
#                                                    'geneName': 'BRCA2',
#                                                    'sequenceOntologyTerms': [{'accession': 'SO:0001631',
#                                                                               'name': 'upstream_gene_variant'}],
#                                                    'strand': '+',
#                                                    'transcriptAnnotationFlags': ['CCDS',
#                                                                                  'basic']},
#                                                   {'biotype': 'protein_coding',
#                                                    'ensemblGeneId': 'ENSG00000139618',
#                                                    'ensemblTranscriptId': 'ENST00000544455',
#                                                    'geneName': 'BRCA2',
#                                                    'sequenceOntologyTerms': [{'accession': 'SO:0001631',
#                                                                               'name': 'upstream_gene_variant'}],
#                                                    'strand': '+',
#                                                    'transcriptAnnotationFlags': ['CCDS',
#                                                                                  'basic']},
#                                                   {'biotype': 'protein_coding',
#                                                    'ensemblGeneId': 'ENSG00000139618',
#                                                    'ensemblTranscriptId': 'ENST00000530893',
#                                                    'geneName': 'BRCA2',
#                                                    'sequenceOntologyTerms': [{'accession': 'SO:0001631',
#                                                                               'name': 'upstream_gene_variant'}],
#                                                    'strand': '+',
#                                                    'transcriptAnnotationFlags': ['mRNA_end_NF',
#                                                                                  'cds_end_NF']},
#                                                   {'sequenceOntologyTerms': [{'accession': 'SO:0001566',
#                                                                               'name': 'regulatory_region_variant'}]},
#                                                   {'sequenceOntologyTerms': [{'accession': 'SO:0001782',
#                                                                               'name': 'TF_binding_site_variant'}]}],
#                              'conservation': [{'score': -1.7599999904632568,
#                                                'source': 'gerp'},
#                                               {'score': 0.0010000000474974513,
#                                                'source': 'phastCons'},
#                                               {'score': -0.37400001287460327,
#                                                'source': 'phylop'}],
#                              'cytoband': [{'chromosome': '13',
#                                            'end': 33400000,
#                                            'name': 'q13.1',
#                                            'stain': 'gpos50',
#                                            'start': 31600001}],
#                              'displayConsequenceType': 'intron_variant',
#                              'functionalScore': [{'score': 0.020000457763671875,
#                                                   'source': 'cadd_raw'},
#                                                  {'score': 2.7899999618530273,
#                                                   'source': 'cadd_scaled'}],
#                              'geneDrugInteraction': [{'drugName': 'BMN673',
#                                                       'geneName': 'BRCA2',
#                                                       'source': 'dgidb',
#                                                       'studyType': 'ClearityFoundationBiomarkers',
#                                                       'type': 'n/a'},
#                                                      {'drugName': 'OLAPARIB',
#                                                       'geneName': 'BRCA2',
#                                                       'source': 'dgidb',
#                                                       'studyType': 'ClearityFoundationBiomarkers',
#                                                       'type': 'n/a'},
#                                                      {'drugName': 'RUCAPARIB',
#                                                       'geneName': 'BRCA2',
#                                                       'source': 'dgidb',
#                                                       'studyType': 'ClearityFoundationBiomarkers',
#                                                       'type': 'n/a'},
#                                                      {'drugName': 'NIRAPARIB',
#                                                       'geneName': 'BRCA2',
#                                                       'source': 'dgidb',
#                                                       'studyType': 'ClearityFoundationBiomarkers',
#                                                       'type': 'n/a'},
#                                                      {'drugName': 'E7449',
#                                                       'geneName': 'BRCA2',
#                                                       'source': 'dgidb',
#                                                       'studyType': 'ClearityFoundationBiomarkers',
#                                                       'type': 'n/a'},
#                                                      {'drugName': 'VELIPARIB',
#                                                       'geneName': 'BRCA2',
#                                                       'source': 'dgidb',
#                                                       'studyType': 'ClearityFoundationBiomarkers',
#                                                       'type': 'n/a'}],
#                              'geneTraitAssociation': [{'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0678222',
#                                                        'name': 'Breast '
#                                                                'Carcinoma',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0006142',
#                                                        'name': 'Malignant '
#                                                                'neoplasm '
#                                                                'breast',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'hpo': 'HP:0000568',
#                                                        'id': 'OMIM:609054',
#                                                        'name': 'Microphthalmia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0003221',
#                                                        'id': 'OMIM:609054',
#                                                        'name': 'Chromosomal '
#                                                                'breakage '
#                                                                'induced by '
#                                                                'crosslinking '
#                                                                'agents',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0005528',
#                                                        'id': 'OMIM:609054',
#                                                        'name': 'Bone marrow '
#                                                                'hypocellularity',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001511',
#                                                        'id': 'OMIM:609054',
#                                                        'name': 'Intrauterine '
#                                                                'growth '
#                                                                'retardation',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0009778',
#                                                        'id': 'OMIM:609054',
#                                                        'name': 'Short thumb',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001263',
#                                                        'id': 'OMIM:609054',
#                                                        'name': 'Global '
#                                                                'developmental '
#                                                                'delay',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000007',
#                                                        'id': 'OMIM:609054',
#                                                        'name': 'Autosomal '
#                                                                'recessive '
#                                                                'inheritance',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0007565',
#                                                        'id': 'OMIM:609054',
#                                                        'name': 'Multiple '
#                                                                'cafe-au-lait '
#                                                                'spots',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0008897',
#                                                        'id': 'OMIM:609054',
#                                                        'name': 'Postnatal '
#                                                                'growth '
#                                                                'retardation',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000028',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Cryptorchidism',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001000',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Abnormality of '
#                                                                'skin '
#                                                                'pigmentation',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0004322',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Short stature',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001873',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Thrombocytopenia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0009943',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Complete '
#                                                                'duplication of '
#                                                                'thumb phalanx',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000978',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Bruising '
#                                                                'susceptibility',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001875',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Neutropenia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000081',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Duplicated '
#                                                                'collecting '
#                                                                'system',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000957',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Cafe-au-lait '
#                                                                'spot',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000085',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Horseshoe '
#                                                                'kidney',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0009777',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Absent thumb',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0003213',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Deficient '
#                                                                'excision of '
#                                                                'UV-induced '
#                                                                'pyrimidine '
#                                                                'dimers in DNA',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000568',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Microphthalmia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0009778',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Short thumb',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001249',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Intellectual '
#                                                                'disability',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001903',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Anemia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001896',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Reticulocytopenia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000086',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Ectopic kidney',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001876',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Pancytopenia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000815',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Hypergonadotropic '
#                                                                'hypogonadism',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000104',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Renal agenesis',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000252',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Microcephaly',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000365',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Hearing '
#                                                                'impairment',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0003974',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Absent radius',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001017',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Anemic pallor',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0003221',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Chromosomal '
#                                                                'breakage '
#                                                                'induced by '
#                                                                'crosslinking '
#                                                                'agents',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000486',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Strabismus',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001909',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Leukemia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0003214',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Prolonged G2 '
#                                                                'phase of cell '
#                                                                'cycle',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0030680',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Abnormality of '
#                                                                'cardiovascular '
#                                                                'system '
#                                                                'morphology',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001518',
#                                                        'id': 'OMIM:600901',
#                                                        'name': 'Small for '
#                                                                'gestational '
#                                                                'age',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0006727',
#                                                        'id': 'OMIM:605724',
#                                                        'name': 'T-cell acute '
#                                                                'lymphoblastic '
#                                                                'leukemias',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0003221',
#                                                        'id': 'OMIM:605724',
#                                                        'name': 'Chromosomal '
#                                                                'breakage '
#                                                                'induced by '
#                                                                'crosslinking '
#                                                                'agents',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0002023',
#                                                        'id': 'OMIM:605724',
#                                                        'name': 'Anal atresia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000007',
#                                                        'id': 'OMIM:605724',
#                                                        'name': 'Autosomal '
#                                                                'recessive '
#                                                                'inheritance',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001511',
#                                                        'id': 'OMIM:605724',
#                                                        'name': 'Intrauterine '
#                                                                'growth '
#                                                                'retardation',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000957',
#                                                        'id': 'OMIM:605724',
#                                                        'name': 'Cafe-au-lait '
#                                                                'spot',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0009778',
#                                                        'id': 'OMIM:605724',
#                                                        'name': 'Short thumb',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000252',
#                                                        'id': 'OMIM:605724',
#                                                        'name': 'Microcephaly',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001508',
#                                                        'id': 'OMIM:605724',
#                                                        'name': 'Failure to '
#                                                                'thrive',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0004808',
#                                                        'id': 'OMIM:605724',
#                                                        'name': 'Acute myeloid '
#                                                                'leukemia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001903',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Anemia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000957',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Cafe-au-lait '
#                                                                'spot',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0003220',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Abnormality of '
#                                                                'chromosome '
#                                                                'stability',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000568',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Microphthalmia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0005528',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Bone marrow '
#                                                                'hypocellularity',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0009777',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Absent thumb',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001511',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Intrauterine '
#                                                                'growth '
#                                                                'retardation',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000175',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Cleft palate',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000316',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Hypertelorism',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000431',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Wide nasal '
#                                                                'bridge',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0002575',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Tracheoesophageal '
#                                                                'fistula',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0005280',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Depressed '
#                                                                'nasal bridge',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0002032',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Esophageal '
#                                                                'atresia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0002023',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Anal atresia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001263',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Global '
#                                                                'developmental '
#                                                                'delay',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001999',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Abnormal '
#                                                                'facial shape',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000054',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Micropenis',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000089',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Renal '
#                                                                'hypoplasia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0008551',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Microtia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000238',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Hydrocephalus',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000007',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Autosomal '
#                                                                'recessive '
#                                                                'inheritance',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000470',
#                                                        'id': 'OMIM:614083',
#                                                        'name': 'Short neck',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0005528',
#                                                        'id': 'OMIM:609053',
#                                                        'name': 'Bone marrow '
#                                                                'hypocellularity',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0030680',
#                                                        'id': 'OMIM:609053',
#                                                        'name': 'Abnormality of '
#                                                                'cardiovascular '
#                                                                'system '
#                                                                'morphology',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0004322',
#                                                        'id': 'OMIM:609053',
#                                                        'name': 'Short stature',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0003221',
#                                                        'id': 'OMIM:609053',
#                                                        'name': 'Chromosomal '
#                                                                'breakage '
#                                                                'induced by '
#                                                                'crosslinking '
#                                                                'agents',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0012210',
#                                                        'id': 'OMIM:609053',
#                                                        'name': 'Abnormal renal '
#                                                                'morphology',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000007',
#                                                        'id': 'OMIM:609053',
#                                                        'name': 'Autosomal '
#                                                                'recessive '
#                                                                'inheritance',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0002885',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Medulloblastoma',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001915',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Aplastic '
#                                                                'anemia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000316',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Hypertelorism',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000286',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Epicanthus',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0003006',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Neuroblastoma',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000007',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Autosomal '
#                                                                'recessive '
#                                                                'inheritance',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0003221',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Chromosomal '
#                                                                'breakage '
#                                                                'induced by '
#                                                                'crosslinking '
#                                                                'agents',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0008897',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Postnatal '
#                                                                'growth '
#                                                                'retardation',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000470',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Short neck',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0002667',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Nephroblastoma '
#                                                                '(Wilms tumor)',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000957',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Cafe-au-lait '
#                                                                'spot',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001629',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Ventricular '
#                                                                'septal defect',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000252',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Microcephaly',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0009778',
#                                                        'id': 'OMIM:610832',
#                                                        'name': 'Short thumb',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000083',
#                                                        'id': 'ORPHANET:84',
#                                                        'name': 'Renal '
#                                                                'insufficiency',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000957',
#                                                        'id': 'ORPHANET:84',
#                                                        'name': 'Cafe-au-lait '
#                                                                'spot',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001199',
#                                                        'id': 'ORPHANET:84',
#                                                        'name': 'Triphalangeal '
#                                                                'thumb',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001562',
#                                                        'id': 'ORPHANET:84',
#                                                        'name': 'Oligohydramnios',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000508',
#                                                        'id': 'ORPHANET:84',
#                                                        'name': 'Ptosis',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000175',
#                                                        'id': 'ORPHANET:84',
#                                                        'name': 'Cleft palate',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0002863',
#                                                        'id': 'ORPHANET:84',
#                                                        'name': 'Myelodysplasia',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0001763',
#                                                        'id': 'ORPHANET:84',
#                                                        'name': 'Pes planus',
#                                                        'source': 'hpo'},
#                                                       {'hpo': 'HP:0000010',
#                                                        'id': 'ORPHANET:84',
#                                                        'name': 'Recurrent '
#                                                                'urinary tract '
#                                                                'infections',
#                                                        'source': 'hpo'},
# ...
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0549473',
#                                                        'name': 'THYROID '
#                                                                'CARCINOMA',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0752347',
#                                                        'name': 'Lewy Body '
#                                                                'Disease',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C1856689',
#                                                        'name': 'Friedreich '
#                                                                'Ataxia 1',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C1334274',
#                                                        'name': 'Invasive '
#                                                                'Carcinoma',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0007115',
#                                                        'name': 'Malignant '
#                                                                'neoplasm '
#                                                                'thyroid',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['GeneticVariation'],
#                                                        'id': 'umls:C0023530',
#                                                        'name': 'Leukopenia',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C1318485',
#                                                        'name': 'Liver '
#                                                                'regeneration',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0887833',
#                                                        'name': 'Carcinoma, '
#                                                                'Pancreatic '
#                                                                'Ductal',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0751690',
#                                                        'name': 'Malignant '
#                                                                'Peripheral '
#                                                                'Nerve Sheath '
#                                                                'Tumor',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0041296',
#                                                        'name': 'Tuberculosis',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C1514428',
#                                                        'name': 'Primary '
#                                                                'Peritoneal '
#                                                                'Carcinoma',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0277554',
#                                                        'name': 'Primary '
#                                                                'disease',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0751887',
#                                                        'name': 'medullary '
#                                                                'tumors',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0424091',
#                                                        'name': 'Loss of '
#                                                                'interest',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0027831',
#                                                        'name': 'Neurofibromatosis '
#                                                                '1',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0205747',
#                                                        'name': 'Familial '
#                                                                'Atypical '
#                                                                'Multiple '
#                                                                'Mole-Melanoma',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0740380',
#                                                        'name': 'varicella '
#                                                                'zoster',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0027066',
#                                                        'name': 'Myoclonus',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C2936349',
#                                                        'name': 'Plaque, '
#                                                                'Amyloid',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0206663',
#                                                        'name': 'Neuroectodermal '
#                                                                'Tumors, '
#                                                                'Primitive',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0302592',
#                                                        'name': 'Cervix '
#                                                                'carcinoma',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0206684',
#                                                        'name': 'Adenocarcinoma, '
#                                                                'Sebaceous',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C1512441',
#                                                        'name': 'High-Risk '
#                                                                'Cancer',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker'],
#                                                        'id': 'umls:C0342276',
#                                                        'name': 'Mason-Type '
#                                                                'Diabetes',
#                                                        'numberOfPubmeds': 1,
#                                                        'score': 0.00028350457,
#                                                        'source': 'disgenet',
#                                                        'sources': ['BeFree']},
#                                                       {'associationTypes': ['Biomarker']
