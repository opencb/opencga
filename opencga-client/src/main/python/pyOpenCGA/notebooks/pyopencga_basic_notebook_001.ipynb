# %% [markdown]
# # pyOpenCGA Basic User Usage [UNDER CONSTRUCTION]
#
# ------
#
#
# **[NOTE]** The server methods used by pyopencga client are defined in the following swagger URL:
# - http://bioinfodev.hpc.cam.ac.uk/opencga-test/webservices
#
# **[NOTE]** Current implemented methods are registered at the following spreadsheet:
# - https://docs.google.com/spreadsheets/d/1QpU9yl3UTneqwRqFX_WAqCiCfZBk5eU-4E3K-WVvuoc/edit?usp=sharing

# %% [markdown]
# ## Loading pyOpenCGA

# %%
# Initialize PYTHONPATH for pyopencga
import sys
import os

cwd = os.getcwd()
print("current_dir: ...."+cwd[-10:])

base_modules_dir = os.path.dirname(cwd)
print("base_modules_dir: ...."+base_modules_dir[-10:])

sys.path.append(base_modules_dir)
# Out:
# current_dir: ..../notebooks
# base_modules_dir: ..../pyOpenCGA

# %%
from pyopencga.opencga_config import ConfigClient
from pyopencga.opencga_client import OpenCGAClient
import json

# %% [markdown]
# ## Setting credentials for LogIn

# %% [markdown]
# **Credentials**
#
# Plese add the credentials for opencga login into a file in json format and read them from there.
#
# i.e:
# file: \__user_config.json
# flie_content: {"user":"xxx","pwd":"yyy"}

# %%
## Reading user config/credentials to connect to server
user_config_json = "./__user_config.json"
with open(user_config_json,"r") as f:
    user_credentials = json.loads(f.read())
    
print('User: {}***'.format(user_credentials["user"][:3]))
# Out:
# User: caf***

# %%
user = user_credentials["user"]
passwd = user_credentials["pwd"]

# %% [markdown]
# ## Creating ConfigClient for server connection configuration

# %%
## Creating ConfigClient
host = 'http://bioinfodev.hpc.cam.ac.uk/opencga-test'
cc = ConfigClient()
config_dict = cc.get_basic_config_dict(host)
print("Config information:\n",config_dict)
# Out:
# Config information:
#  {'version': 'v1', 'rest': {'hosts': ['http://bioinfodev.hpc.cam.ac.uk/opencga-test']}}

# %% [markdown]
# ## LogIn with user credentials

# %%
oc = OpenCGAClient(configuration=config_dict, 
                   user=user, 
                   pwd=passwd)

# %%
## Getting the session id / token
token = oc.session_id
print("Session token:\n{}...".format(token[:10]))
# Out:
# Session token:
# eyJhbGciOi...

# %%
oc = OpenCGAClient(configuration=config_dict, 
                   session_id=token)

# %%
## test to check if multiple extra parameters work
fc = oc.files
fc.search(study = "cafetero@GRCH37:platinum", type="FILE")
# Out:
# [[{'id': 'tmp:HG00096.chrom20.small.bam',
#    'annotationSets': [],
#    'name': 'HG00096.chrom20.small.bam',
#    'uuid': 'TM9SrwFoAAMAAR5FsdmSkQ',
#    'type': 'FILE',
#    'format': 'BAM',
#    'bioformat': 'ALIGNMENT',
#    'checksum': '',
#    'uri': 'file:///tmp/HG00096.chrom20.small.bam',
#    'path': 'tmp/HG00096.chrom20.small.bam',
#    'release': 1,
#    'creationDate': '20190114144122',
#    'modificationDate': '20190306123127',
#    'description': '',
#    'status': {'name': 'MISSING', 'date': '20190306123127', 'message': ''},
#    'external': True,
#    'size': 15397,
#    'experiment': {},
#    'samples': [{'id': 'HG00096',
#      'uuid': 'TM9TegFoAAQAARYSE1KsKQ',
#      'source': 'HG00096.chrom20.small.bam',
#      'individual': {'release': 0,
#       'version': 0,
#       'parentalConsanguinity': False},
#      'release': 1,
#      'version': 1,
#      'creationDate': '20190114144122',
#      'status': {'name': 'READY', 'date': '20190114144122', 'message': ''},
#      'description': '',
#      'type': '',
#      'somatic': False,
#      'phenotypes': [],
#      'stats': {},
#      'attributes': {}}],
#    'tags': [],
#    'job': {'startTime': 0,
#     'endTime': 0,
#     'visited': False,
#     'size': 0,
#     'release': 0},
#    'relatedFiles': [],
#    'index': {'jobId': 0, 'release': 0},
#    'stats': {'globalStats': '{"numMapped":108,"numUnmapped":0,"numPaired":104,"numMappedFirst":53,"numMappedSecond":55,"NM":49,"numHardC":0,"numSoftC":35,"numIn":0,"numDel":0,"numPad":0,"numSkip":0,"accMappingQuality":6226,"mappingQualityMap":{"48":2,"37":10,"60":96},"accInsert":19175,"insertMap":{"192":4,"193":4,"195":4,"196":4,"134":2,"198":4,"135":4,"199":1,"200":4,"137":2,"202":4,"138":2,"203":2,"205":2,"210":2,"211":4,"212":2,"218":2,"219":2,"221":2,"158":2,"162":2,"165":2,"167":4,"168":2,"170":4,"172":2,"173":2,"177":2,"178":2,"179":4,"180":2,"183":2,"184":4,"185":3,"186":2,"188":2,"189":1,"190":3},"seqStats":{"numSeqs":108,"numA":3462,"numT":2260,"numG":2480,"numC":2587,"numN":11,"minSeqLength":100,"maxSeqLength":100,"accSeqQual":334978,"lengthMap":{"100":108},"infoMap":{"0":{"numA":32,"numT":24,"numG":22,"numC":30,"numN":0,"numQual":108,"accQual":1879},"1":{"numA":38,"numT":16,"numG":32,"numC":22,"numN":0,"numQual":108,"accQual":2995},"2":{"numA":29,"numT":20,"numG":40,"numC":19,"numN":0,"numQual":108,"accQual":2975},"3":{"numA":38,"numT":24,"numG":25,"numC":21,"numN":0,"numQual":108,"accQual":3009},"4":{"numA":34,"numT":25,"numG":24,"numC":25,"numN":0,"numQual":108,"accQual":3075},"5":{"numA":31,"numT":19,"numG":28,"numC":30,"numN":0,"numQual":108,"accQual":3098},"6":{"numA":41,"numT":20,"numG":23,"numC":24,"numN":0,"numQual":108,"accQual":3155},"7":{"numA":29,"numT":24,"numG":21,"numC":34,"numN":0,"numQual":108,"accQual":3096},"8":{"numA":35,"numT":20,"numG":20,"numC":33,"numN":0,"numQual":108,"accQual":3178},"9":{"numA":35,"numT":20,"numG":29,"numC":24,"numN":0,"numQual":108,"accQual":3198},"10":{"numA":39,"numT":19,"numG":24,"numC":26,"numN":0,"numQual":108,"accQual":3234},"11":{"numA":34,"numT":19,"numG":31,"numC":24,"numN":0,"numQual":108,"accQual":3214},"12":{"numA":41,"numT":22,"numG":20,"numC":25,"numN":0,"numQual":108,"accQual":3259},"13":{"numA":37,"numT":21,"numG":27,"numC":23,"numN":0,"numQual":108,"accQual":3229},"14":{"numA":34,"numT":31,"numG":24,"numC":19,"numN":0,"numQual":108,"accQual":3237},"15":{"numA":31,"numT":29,"numG":23,"numC":25,"numN":0,"numQual":108,"accQual":3292},"16":{"numA":33,"numT":21,"numG":31,"numC":23,"numN":0,"numQual":108,"accQual":3292},"17":{"numA":39,"numT":27,"numG":24,"numC":18,"numN":0,"numQual":108,"accQual":3344},"18":{"numA":36,"numT":24,"numG":26,"numC":22,"numN":0,"numQual":108,"accQual":3335},"19":{"numA":30,"numT":23,"numG":26,"numC":29,"numN":0,"numQual":108,"accQual":3381},"20":{"numA":32,"numT":27,"numG":25,"numC":24,"numN":0,"numQual":108,"accQual":3329},"21":{"numA":35,"numT":18,"numG":27,"numC":28,"numN":0,"numQual":108,"accQual":3458},"22":{"numA":35,"numT":26,"numG":24,"numC":23,"numN":0,"numQual":108,"accQual":3375},"23":{"numA":32,"numT":21,"numG":30,"numC":25,"numN":0,"numQual":108,"accQual":3326},"24":{"numA":37,"numT":27,"numG":17,"numC":27,"numN":0,"numQual":108,"accQual":3412},"25":{"numA":46,"numT":26,"numG":19,"numC":17,"numN":0,"numQual":108,"accQual":3493},"26":{"numA":32,"numT":19,"numG":28,"numC":29,"numN":0,"numQual":108,"accQual":3434},"27":{"numA":45,"numT":15,"numG":23,"numC":25,"numN":0,"numQual":108,"accQual":3419},"28":{"numA":29,"numT":24,"numG":21,"numC":34,"numN":0,"numQual":108,"accQual":3378},"29":{"numA":38,"numT":26,"numG":18,"numC":26,"numN":0,"numQual":108,"accQual":3467},"30":{"numA":34,"numT":26,"numG":21,"numC":27,"numN":0,"numQual":108,"accQual":3393},"31":{"numA":35,"numT":23,"numG":28,"numC":21,"numN":1,"numQual":108,"accQual":3356},"32":{"numA":28,"numT":26,"numG":24,"numC":29,"numN":1,"numQual":108,"accQual":3367},"33":{"numA":46,"numT":13,"numG":24,"numC":24,"numN":1,"numQual":108,"accQual":3390},"34":{"numA":38,"numT":24,"numG":18,"numC":27,"numN":1,"numQual":108,"accQual":3390},"35":{"numA":40,"numT":24,"numG":21,"numC":22,"numN":1,"numQual":108,"accQual":3387},"36":{"numA":31,"numT":21,"numG":23,"numC":33,"numN":0,"numQual":108,"accQual":3483},"37":{"numA":37,"numT":21,"numG":27,"numC":23,"numN":0,"numQual":108,"accQua ...
#    'attributes': {'alignmentHeader': {'attributes': {},
#      'sequenceDiccionary': [{'sequenceName': '1',
#        'sequenceLength': 249250621,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '1b22b98cdeb4a9304cb5d48026a85128',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '2',
#        'sequenceLength': 243199373,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'a0d9851da00400dec1098a9255ac712e',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '3',
#        'sequenceLength': 198022430,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'fdfd811849cc2fadebc929bb925902e5',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '4',
#        'sequenceLength': 191154276,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '23dccd106897542ad87d2765d28a19a1',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '5',
#        'sequenceLength': 180915260,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '0740173db9ffd264d728f32784845cd7',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '6',
#        'sequenceLength': 171115067,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '1d3a93a248d92a729ee764823acbbc6b',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '7',
#        'sequenceLength': 159138663,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '618366e953d6aaad97dbe4777c29375e',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '8',
#        'sequenceLength': 146364022,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '96f514a9929e410c6651697bded59aec',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '9',
#        'sequenceLength': 141213431,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '3e273117f15e0a400f01055d9f393768',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '10',
#        'sequenceLength': 135534747,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '988c28e000e84c26d552359af1ea2e1d',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '11',
#        'sequenceLength': 135006516,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '98c59049a2df285c76ffb1c6db8f8b96',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '12',
#        'sequenceLength': 133851895,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '51851ac0e1a115847ad36449b0015864',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '13',
#        'sequenceLength': 115169878,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '283f8d7892baa81b510a015719ca7b0b',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '14',
#        'sequenceLength': 107349540,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '98f3cae32b2a2e9524bc19813927542e',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '15',
#        'sequenceLength': 102531392,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'e5645a794a8238215b2cd77acb95a078',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '16',
#        'sequenceLength': 90354753,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'fc9b1a7b42b97a864f56b348b06095e6',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '17',
#        'sequenceLength': 81195210,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '351f64d4f4f9ddd45b35336ad97aa6de',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '18',
#        'sequenceLength': 78077248,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'b15d4b2d29dde9d3e4f93d1d0f2cbc9c',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '19',
#        'sequenceLength': 59128983,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '1aacd71f30db8e561810913e0b72636d',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '20',
#        'sequenceLength': 63025520,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '0dec9660ec1efaaf33281c0d5ea2560f',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '21',
#        'sequenceLength': 48129895,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '2979a6085bfe28e3ad6f552f361ed74d',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': '22',
#        'sequenceLength': 51304566,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'a718acaa6135fdca8357d5bfe94211dd',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'X',
#        'sequenceLength': 155270560,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '7e0e2e580297b7764e31dbc80c2540dd',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'Y',
#        'sequenceLength': 59373566,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '1fa3474750af0948bdf97d5a0ee52e51',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'MT',
#        'sequenceLength': 16569,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'c68f52674c9fb33aef52dcf399755519',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000207.1',
#        'sequenceLength': 4262,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'f3814841f1939d3ca19072d9e89f3fd7',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000226.1',
#        'sequenceLength': 15008,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '1c1b2cd1fccbc0a99b6a447fa24d1504',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000229.1',
#        'sequenceLength': 19913,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'd0f40ec87de311d8e715b52e4c7062e1',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000231.1',
#        'sequenceLength': 27386,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'ba8882ce3a1efa2080e5d29b956568a4',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000210.1',
#        'sequenceLength': 27682,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '851106a74238044126131ce2a8e5847c',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000239.1',
#        'sequenceLength': 33824,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '99795f15702caec4fa1c4e15f8a29c07',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000235.1',
#        'sequenceLength': 34474,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '118a25ca210cfbcdfb6c2ebb249f9680',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000201.1',
#        'sequenceLength': 36148,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'dfb7e7ec60ffdcb85cb359ea28454ee9',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000247.1',
#        'sequenceLength': 36422,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '7de00226bb7df1c57276ca6baabafd15',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000245.1',
#        'sequenceLength': 36651,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '89bc61960f37d94abf0df2d481ada0ec',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000197.1',
#        'sequenceLength': 37175,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '6f5efdd36643a9b8c8ccad6f2f1edc7b',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000203.1',
#        'sequenceLength': 37498,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '96358c325fe0e70bee73436e8bb14dbd',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000246.1',
#        'sequenceLength': 38154,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'e4afcd31912af9d9c2546acf1cb23af2',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000249.1',
#        'sequenceLength': 38502,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '1d78abec37c15fe29a275eb08d5af236',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000196.1',
#        'sequenceLength': 38914,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'd92206d1bb4c3b4019c43c0875c06dc0',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000248.1',
#        'sequenceLength': 39786,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '5a8e43bec9be36c7b49c84d585107776',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000244.1',
#        'sequenceLength': 39929,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '0996b4475f353ca98bacb756ac479140',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000238.1',
#        'sequenceLength': 39939,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '131b1efc3270cc838686b54e7c34b17b',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000202.1',
#        'sequenceLength': 40103,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '06cbf126247d89664a4faebad130fe9c',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000234.1',
#        'sequenceLength': 40531,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '93f998536b61a56fd0ff47322a911d4b',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000232.1',
#        'sequenceLength': 40652,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '3e06b6741061ad93a8587531307057d8',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000206.1',
#        'sequenceLength': 41001,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '43f69e423533e948bfae5ce1d45bd3f1',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000240.1',
#        'sequenceLength': 41933,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '445a86173da9f237d7bcf41c6cb8cc62',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000236.1',
#        'sequenceLength': 41934,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'fdcd739913efa1fdc64b6c0cd7016779',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000241.1',
#        'sequenceLength': 42152,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'ef4258cdc5a45c206cea8fc3e1d858cf',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000243.1',
#        'sequenceLength': 43341,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'cc34279a7e353136741c9fce79bc4396',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000242.1',
#        'sequenceLength': 43523,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '2f8694fc47576bc81b5fe9e7de0ba49e',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000230.1',
#        'sequenceLength': 43691,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'b4eb71ee878d3706246b7c1dbef69299',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000237.1',
#        'sequenceLength': 45867,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'e0c82e7751df73f4f6d0ed30cdc853c0',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000233.1',
#        'sequenceLength': 45941,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '7fed60298a8d62ff808b74b6ce820001',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000204.1',
#        'sequenceLength': 81310,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'efc49c871536fa8d79cb0a06fa739722',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000198.1',
#        'sequenceLength': 90085,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '868e7784040da90d900d2d1b667a1383',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000208.1',
#        'sequenceLength': 92689,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'aa81be49bf3fe63a79bdc6a6f279abf6',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000191.1',
#        'sequenceLength': 106433,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'd75b436f50a8214ee9c2a51d30b2c2cc',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000227.1',
#        'sequenceLength': 128374,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'a4aead23f8053f2655e468bcc6ecdceb',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000228.1',
#        'sequenceLength': 129120,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'c5a17c97e2c1a0b6a9cc5a6b064b714f',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000214.1',
#        'sequenceLength': 137718,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '46c2032c37f2ed899eb41c0473319a69',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000221.1',
#        'sequenceLength': 155397,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '3238fb74ea87ae857f9c7508d315babb',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000209.1',
#        'sequenceLength': 159169,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'f40598e2a5a6b26e84a3775e0d1e2c81',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000218.1',
#        'sequenceLength': 161147,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '1d708b54644c26c7e01c2dad5426d38c',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000220.1',
#        'sequenceLength': 161802,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'fc35de963c57bf7648429e6454f1c9db',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000213.1',
#        'sequenceLength': 164239,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '9d424fdcc98866650b58f004080a992a',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000211.1',
#        'sequenceLength': 166566,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '7daaa45c66b288847b9b32b964e623d3',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000199.1',
#        'sequenceLength': 169874,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '569af3b73522fab4b40995ae4944e78e',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000217.1',
#        'sequenceLength': 172149,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '6d243e18dea1945fb7f2517615b8f52e',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000216.1',
#        'sequenceLength': 172294,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '642a232d91c486ac339263820aef7fe0',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000215.1',
#        'sequenceLength': 172545,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '5eb3b418480ae67a997957c909375a73',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000205.1',
#        'sequenceLength': 174588,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'd22441398d99caf673e9afb9a1908ec5',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000219.1',
#        'sequenceLength': 179198,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'f977edd13bac459cb2ed4a5457dba1b3',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000224.1',
#        'sequenceLength': 179693,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'd5b2fc04f6b41b212a4198a07f450e20',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000223.1',
#        'sequenceLength': 180455,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '399dfa03bf32022ab52a846f7ca35b30',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000195.1',
#        'sequenceLength': 182896,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '5d9ec007868d517e73543b005ba48535',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000212.1',
#        'sequenceLength': 186858,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '563531689f3dbd691331fd6c5730a88b',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000222.1',
#        'sequenceLength': 186861,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '6fe9abac455169f50470f5a6b01d0f59',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000200.1',
#        'sequenceLength': 187035,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '75e4c8d17cd4addf3917d1703cacaf25',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000193.1',
#        'sequenceLength': 189789,
#        'attributes': {'AS': 'NCBI37',
#         'M5': 'dbb6e8ece0b5de29da56601613007c2a',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000194.1',
#        'sequenceLength': 191469,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '6ac8f815bf8e845bb3031b73f812c012',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000225.1',
#        'sequenceLength': 211173,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '63945c3e6962f28ffd469719a747e73c',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}},
#       {'sequenceName': 'GL000192.1',
#        'sequenceLength': 547496,
#        'attributes': {'AS': 'NCBI37',
#         'M5': '325ba9e808f669dfeee210fdd7b470ac',
#         'UR': 'ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/technical/reference/human_g1k_v37.fasta.gz',
#         'SP': 'Human'}}],
#      'readGroups': [{'id': 'SRR062634',
#        'attributes': {'LB': '2845856850',
#         'PI': '206',
#         'SM': 'HG00096',
#         'CN': 'WUGSC',
#         'PL': 'ILLUMINA',
#         'DS': 'SRP001294'}},
#       {'id': 'SRR062635',
#        'attributes': {'LB': '2845856850',
#         'PI': '206',
#         'SM': 'HG00096',
#         'CN': 'WUGSC',
#         'PL': 'ILLUMINA',
#         'DS': 'SRP001294'}},
#       {'id': 'SRR062641',
#        'attributes': {'LB': '2845856850',
#         'PI': '206',
#         'SM': 'HG00096',
#         'CN': 'WUGSC',
#         'PL': 'ILLUMINA',
#         'DS': 'SRP001294'}}],
#      'programRecords': [{'id': 'GATK IndelRealigner',
#        'attributes': {'VN': '1.0.4487',
#         'CL': 'SNPsFileForDebugging=null targetIntervals=/lustre/scratch105/projects/g1k/ref/broad_recal_data/pilot_data/indel.dbsnp_129_b37-vs-pilot.intervals output=null useOnlyKnownIndels=true maxReadsForConsensuses=120 maxConsensuses=30 entropyThreshold=0.15 indelsFileForDebugging=null noOriginalAlignmentTags=false realignReadsWithBadMates=false maxReadsForRealignment=20000 noPGTag=false LODThresholdForCleaning=0.4 maxReadsInRam=500000 targetIntervalsAreNotSorted=false sortInCoordinateOrderEvenThoughItIsHighlyUnsafe=false statisticsFileForDebugging=null'}},
#       {'id': 'GATK TableRecalibration',
#        'attributes': {'VN': '1.0.4702',
#         'CL': 'default_read_group=RG default_platform=ILLUMINA force_read_group=null force_platform=null window_size_nqs=5 homopolymer_nback=7 exception_if_no_tile=false solid_recal_mode=SET_Q_ZERO solid_nocall_strategy=THROW_EXCEPTION output_bam=null preserve_qscores_less_than=5 smoothing=1 max_quality_score=40 no_pg_tag=false fail_with_no_eof_marker=true skipUQUpdate=false Covariates=[ReadGroupCovariate, QualityScoreCovariate, CycleCovariate, DinucCovariate] pQ=5 maxQ=40 smoothing=1'}},
#       {'id': 'GATK TableRecalibration.1',
#        'attributes': {'VN': '1.0.4487',
#         'CL': 'output_bam=null window_size_nqs=5 force_read_group=null smoothing=1 default_platform=ILLUMINA exception_if_no_tile=false homopolymer_nback=7 no_pg_tag=false skipUQUpdate=false default_read_group=RG max_quality_score=40 fail_with_no_eof_marker=true solid_recal_mode=SET_Q_ZERO solid_nocall_strategy=THROW_EXCEPTION force_platform=null preserve_qscores_less_than=5 Covariates=[ReadGroupCovariate, QualityScoreCovariate, CycleCovariate, DinucCovariate] pQ=5 maxQ=40 smoothing=1'}},
#       {'id': 'bwa', 'attributes': {'VN': '0.5.5'}}],
#      'comments': [],
#      'studyName': 'Platinum',
#      'origin': 'SAM'}}},
#   {'id': 'data:platinum-genomes-vcf-NA12877_S1.genome.vcf.gz',
#    'annotationSets': [],
#    'name': 'platinum-genomes-vcf-NA12877_S1.genome.vcf.gz',
#    'uuid': '7RrmjQFlAAMAAUQhWCKtIg',
#    'type': 'FILE',
#    'format': 'VCF',
#    'bioformat': 'VARIANT',
#    'checksum': '',
#    'uri': 'file:///mnt/data/downloads/datasets/vcf/platinum_genomes/gz/platinum-genomes-vcf-NA12877_S1.genome.vcf.gz',
#    'path': 'data/platinum-genomes-vcf-NA12877_S1.genome.vcf.gz',
#    'release': 1,
#    'creationDate': '20180918143447',
#    'modificationDate': '20180919113915',
#    'description': '',
#    'status': {'name': 'READY', 'date': '20180918143447', 'message': ''},
#    'external': True,
#    'size': 887890738,
#    'experiment': {},
#    'samples': [{'id': 'NA12877',
#      'uuid': '7RrnvgFlAAQAAfde27jGkg',
#      'source': 'platinum-genomes-vcf-NA12877_S1.genome.vcf.gz',
#      'individual': {'release': 0,
#       'version': 0,
#       'parentalConsanguinity': False},
#      'release': 1,
#      'version': 1,
#      'creationDate': '20180918143448',
#      'status': {'name': 'READY', 'date': '20180918143448', 'message': ''},
#      'description': '',
#      'type': '',
#      'somatic': False,
#      'phenotypes': [],
#      'stats': {},
#      'attributes': {}}],
#    'tags': [],
#    'job': {'startTime': 0,
#     'endTime': 0,
#     'visited': False,
#     'size': 0,
#     'release': 0},
#    'relatedFiles': [],
#    'index': {'status': {'name': 'READY',
#      'date': '20180918155042',
#      'message': 'Start indexing file'},
#     'jobId': 0,
#     'release': 0},
#    'stats': {},
#    'attributes': {'variantFileMetadata': {'header': {'version': 'VCFv4.2',
#       'complexLines': [{'key': 'FORMAT',
#         'id': 'GQX',
#         'description': 'Minimum of {Genotype quality assuming variant position,Genotype quality assuming non-variant position}',
#         'number': '1',
#         'type': 'Integer',
#         'genericFields': {}},
#        {'key': 'FORMAT',
#         'id': 'AD',
#         'description': 'Allelic depths for the ref and alt alleles in the order listed',
#         'number': 'R',
#         'type': 'Integer',
#         'genericFields': {}},
#        {'key': 'FORMAT',
#         'id': 'DP',
#         'description': 'Approximate read depth (reads with MQ=255 or with bad mates are filtered)',
#         'number': '1',
#         'type': 'Integer',
#         'genericFields': {}},
#        {'key': 'FORMAT',
#         'id': 'GQ',
#         'description': 'Genotype Quality',
#         'number': '1',
#         'type': 'Integer',
#         'genericFields': {}},
#        {'key': 'FORMAT',
#         'id': 'GT',
#         'description': 'Genotype',
#         'number': '1',
#         'type': 'String',
#         'genericFields': {}},
#        {'key': 'FORMAT',
#         'id': 'MQ',
#         'description': 'RMS Mapping Quality',
#         'number': '1',
#         'type': 'Integer',
#         'genericFields': {}},
#        {'key': 'FORMAT',
#         'id': 'PL',
#         'description': 'Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification',
#         'number': 'G',
#         'type': 'Integer',
#         'genericFields': {}},
#        {'key': 'FORMAT',
#         'id': 'VF',
#         'description': 'Variant Frequency, the ratio of the sum of the called variant depth to the total depth',
#         'number': '1',
#         'type': 'Float',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'AC',
#         'description': 'Allele count in genotypes, for each ALT allele, in the same order as listed',
#         'number': 'A',
#         'type': 'Integer',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'AF',
#         'description': 'Allele Frequency, for each ALT allele, in the same order as listed',
#         'number': 'A',
#         'type': 'Float',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'AN',
#         'description': 'Total number of alleles in called genotypes',
#         'number': '1',
#         'type': 'Integer',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'DP',
#         'description': 'Approximate read depth; some reads may have been filtered',
#         'number': '1',
#         'type': 'Integer',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'QD',
#         'description': 'Variant Confidence/Quality by Depth',
#         'number': '1',
#         'type': 'Float',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'BLOCKAVG_min30p3a',
#         'description': 'Non-variant site block. All sites in a block are constrained to be non-variant, have the same filter value, and have all sample values in range [x,y], y <= max(x+3,(x*1.3)). All printed site block sample values are the minimum observed in the region spanned by the block',
#         'number': '0',
#         'type': 'Flag',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'BaseQRankSum',
#         'description': 'Z-score from Wilcoxon rank sum test of Alt Vs. Ref base qualities',
#         'number': '1',
#         'type': 'Float',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'DS',
#         'description': 'Were any of the samples downsampled?',
#         'number': '0',
#         'type': 'Flag',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'Dels',
#         'description': 'Fraction of Reads Containing Spanning Deletions',
#         'number': '1',
#         'type': 'Float',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'END',
#         'description': 'End position of the region described in this record',
#         'number': '1',
#         'type': 'Integer',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'FS',
#         'description': "Phred-scaled p-value using Fisher's exact test to detect strand bias",
#         'number': '1',
#         'type': 'Float',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'HRun',
#         'description': 'Largest Contiguous Homopolymer Run of Variant Allele In Either Direction',
#         'number': '1',
#         'type': 'Integer',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'HaplotypeScore',
#         'description': 'Consistency of the site with at most two segregating haplotypes',
#         'number': '1',
#         'type': 'Float',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'InbreedingCoeff',
#         'description': 'Inbreeding coefficient as estimated from the genotype likelihoods per-sample when compared against the Hardy-Weinberg expectation',
#         'number': '1',
#         'type': 'Float',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'MQ',
#         'description': 'RMS Mapping Quality',
#         'number': '1',
#         'type': 'Float',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'MQ0',
#         'description': 'Total Mapping Quality Zero Reads',
#         'number': '1',
#         'type': 'Integer',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'MQRankSum',
#         'description': 'Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities',
#         'number': '1',
#         'type': 'Float',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'ReadPosRankSum',
#         'description': 'Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias',
#         'number': '1',
#         'type': 'Float',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'SB',
#         'description': 'Strand Bias',
#         'number': '1',
#         'type': 'Float',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'VQSLOD',
#         'description': 'Log odds ratio of being a true variant versus being false under the trained gaussian mixture model',
#         'number': '1',
#         'type': 'Float',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'culprit',
#         'description': 'The annotation which was the worst performing in the Gaussian mixture model, likely the reason why the variant was filtered out',
#         'number': '1',
#         'type': 'String',
#         'genericFields': {}},
#        {'key': 'INFO',
#         'id': 'set',
#         'description': 'Source VCF for the merged record in CombineVariants',
#         'number': '1',
#         'type': 'String',
#         'genericFields': {}},
#        {'key': 'FILTER',
#         'id': 'LowGQX',
#         'description': 'Locus GQX is less than 30.0000 or not present',
#         'genericFields': {}},
#        {'key': 'FILTER',
#         'id': 'LowQD',
#         'description': 'Locus QD is less than 2.0000',
#         'genericFields': {}},
#        {'key': 'FILTER',
#         'id': 'LowMQ',
#         'description': 'Site MQ is less than 20.0000',
#         'genericFields': {}},
#        {'key': 'FILTER',
#         'id': 'IndelConflict',
#         'description': 'Locus is in region with conflicting indel calls.',
#         'genericFields': {}},
#        {'key': 'FILTER',
#         'id': 'MaxDepth',
#         'description': 'Site depth is greater than 3.0x the mean chromosome depth',
#         'genericFields': {}},
#        {'key': 'FILTER',
#         'id': 'SiteConflict',
#         'description': 'Site genotype conflicts with proximal indel call. This is typically a heterozygous SNV call made inside of a heterozygous deletion.',
#         'genericFields': {}},
#        {'key': 'FILTER',
#         'id': 'TruthSensitivityTranche99.00to99.90',
#         'description': 'Truth sensitivity tranche level at VSQ Lod: -1.8337 <= x < -0.5214',
#         'genericFields': {}},
#        {'key': 'FILTER',
#         'id': 'TruthSensitivityTranche99.90to100.00+',
#         'description': 'Truth sensitivity tranche level at VQS Lod < -48.5831',
#         'genericFields': {}},
#        {'key': 'FILTER',
#         'id': 'TruthSensitivityTranche99.90to100.00',
#         'description': 'Truth sensitivity tranche level at VSQ Lod: -48.5831 <= x < -1.8337',
#         'genericFields': {}},
#        {'key': 'contig',
#         'id': 'chr1',
#         'genericFields': {'length': '249250621'}},
#        {'key': 'contig',
#         'id': 'chr10',
#         'genericFields': {'length': '135534747'}},
#        {'key': 'contig',
#         'id': 'chr11',
#         'genericFields': {'length': '135006516'}},
#        {'key': 'contig',
#         'id': 'chr12',
#         'genericFields': {'length': '133851895'}},
#        {'key': 'contig',
#         'id': 'chr13',
#         'genericFields': {'length': '115169878'}},
#        {'key': 'contig',
#         'id': 'chr14',
#         'genericFields': {'length': '107349540'}},
#        {'key': 'contig',
#         'id': 'chr15',
#         'genericFields': {'length': '102531392'}},
#        {'key': 'contig',
#         'id': 'chr16',
#         'genericFields': {'length': '90354753'}},
#        {'key': 'contig',
#         'id': 'chr17',
#         'genericFields': {'length': '81195210'}},
#        {'key': 'contig',
#         'id': 'chr18',
#         'genericFields': {'length': '78077248'}},
#        {'key': 'contig',
#         'id': 'chr19',
#         'genericFields': {'length': '59128983'}},
#        {'key': 'contig',
#         'id': 'chr2',
#         'genericFields': {'length': '243199373'}},
#        {'key': 'contig',
#         'id': 'chr20',
#         'genericFields': {'length': '63025520'}},
#        {'key': 'contig',
#         'id': 'chr21',
#         'genericFields': {'length': '48129895'}},
#        {'key': 'contig',
#         'id': 'chr22',
#         'genericFields': {'length': '51304566'}},
#        {'key': 'contig',
#         'id': 'chr3',
#         'genericFields': {'length': '198022430'}},
#        {'key': 'contig',
#         'id': 'chr4',
#         'genericFields': {'length': '191154276'}},
#        {'key': 'contig',
#         'id': 'chr5',
#         'genericFields': {'length': '180915260'}},
#        {'key': 'contig',
#         'id': 'chr6',
#         'genericFields': {'length': '171115067'}},
#        {'key': 'contig',
#         'id': 'chr7',
#         'genericFields': {'length': '159138663'}},
#        {'key': 'contig',
#         'id': 'chr8',
#         'genericFields': {'length': '146364022'}},
#        {'key': 'contig',
#         'id': 'chr9',
#         'genericFields': {'length': '141213431'}},
#        {'key': 'contig', 'id': 'chrM', 'genericFields': {'length': '16571'}},
#        {'key': 'contig',
#         'id': 'chrX',
#         'genericFields': {'length': '155270560'}},
#        {'key': 'contig',
#         'id': 'chrY',
#         'genericFields': {'length': '59373566'}}],
#       'simpleLines': [{'key': 'ApplyRecalibration',
#         'value': '"analysis_type=ApplyRecalibration input_file=[] read_buffer_size=null phone_home=NO_ET gatk_key=null read_filter=[] intervals=null excludeIntervals=null interval_set_rule=UNION interval_merging=ALL reference_sequence=/illumina/development/Isis/Genomes/Homo_sapiens/UCSC/hg19/Sequence/WholeGenomeFASTA/genome.fa nonDeterministicRandomSeed=false downsampling_type=BY_SAMPLE downsample_to_fraction=null downsample_to_coverage=1000 baq=OFF baqGapOpenPenalty=40.0 performanceLog=null useOriginalQualities=false BQSR=null quantize_quals=-1 defaultBaseQualities=-1 validation_strictness=SILENT unsafe=null num_threads=1 num_cpu_threads=null num_io_threads=null num_bam_file_handles=null read_group_black_list=null pedigree=[] pedigreeString=[] pedigreeValidationType=STRICT allow_intervals_with_unindexed_bam=false logging_level=INFO log_to_file=null help=false input=[(RodBinding name=input source=/illumina/builds/platinumgenomes/Platinum_Genomes_Short_Insert/bwa_0.6.1/NA12877/Data/Intensities/BaseCalls/Alignment/tempvariants_G1.1.Indel.txt)] recal_file=(RodBinding name=recal_file source=/illumina/builds/platinumgenomes/Platinum_Genomes_Short_Insert/bwa_0.6.1/NA12877/Data/Intensities/BaseCalls/Alignment/tempvariants_G1.1.vcf.1.recal) tranches_file=/illumina/builds/platinumgenomes/Platinum_Genomes_Short_Insert/bwa_0.6.1/NA12877/Data/Intensities/BaseCalls/Alignment/tempvariants_G1.1.vcf.1.tranches out=org.broadinstitute.sting.gatk.io.stubs.VCFWriterStub NO_HEADER=org.broadinstitute.sting.gatk.io.stubs.VCFWriterStub sites_only=org.broadinstitute.sting.gatk.io.stubs.VCFWriterStub ts_filter_level=99.0 ignore_filter=null mode=INDEL filter_mismatching_base_and_quals=false"'},
#        {'key': 'CombineVariants',
#         'value': '"analysis_type=CombineVariants input_file=[] read_buffer_size=null phone_home=NO_ET gatk_key=null read_filter=[] intervals=null excludeIntervals=null interval_set_rule=UNION interval_merging=ALL reference_sequence=/illumina/development/Isis/Genomes/Homo_sapiens/UCSC/hg19/Sequence/WholeGenomeFASTA/genome.fa nonDeterministicRandomSeed=false downsampling_type=BY_SAMPLE downsample_to_fraction=null downsample_to_coverage=1000 baq=OFF baqGapOpenPenalty=40.0 performanceLog=null useOriginalQualities=false BQSR=null quantize_quals=-1 defaultBaseQualities=-1 validation_strictness=SILENT unsafe=null num_threads=1 num_cpu_threads=null num_io_threads=null num_bam_file_handles=null read_group_black_list=null pedigree=[] pedigreeString=[] pedigreeValidationType=STRICT allow_intervals_with_unindexed_bam=false logging_level=INFO log_to_file=null help=false variant=[(RodBinding name=variant source=/illumina/builds/platinumgenomes/Platinum_Genomes_Short_Insert/bwa_0.6.1/NA12877/Data/Intensities/BaseCalls/Alignment/tempvariants_G1.1.vcf.0.output), (RodBinding name=variant2 source=/illumina/builds/platinumgenomes/Platinum_Genomes_Short_Insert/bwa_0.6.1/NA12877/Data/Intensities/BaseCalls/Alignment/tempvariants_G1.1.vcf.1.output)] out=org.broadinstitute.sting.gatk.io.stubs.VCFWriterStub NO_HEADER=org.broadinstitute.sting.gatk.io.stubs.VCFWriterStub sites_only=org.broadinstitute.sting.gatk.io.stubs.VCFWriterStub genotypemergeoption=PRIORITIZE filteredrecordsmergetype=KEEP_IF_ANY_UNFILTERED multipleallelesmergetype=BY_TYPE rod_priority_list=variant2,variant printComplexMerges=false filteredAreUncalled=false minimalVCF=false setKey=set assumeIdenticalSamples=false minimumN=1 suppressCommandLineHeader=false mergeInfoWithMaxAC=false filter_mismatching_base_and_quals=false"'},
#        {'key': 'MaxDepth_chr10', 'value': '169.26'},
#        {'key': 'MaxDepth_chr11', 'value': '158.94'},
#        {'key': 'MaxDepth_chr12', 'value': '159.84'},
#        {'key': 'MaxDepth_chr13', 'value': '136.65'},
#        {'key': 'MaxDepth_chr14', 'value': '136.44'},
#        {'key': 'MaxDepth_chr15', 'value': '131.73'},
#        {'key': 'MaxDepth_chr16', 'value': '157.29'},
#        {'key': 'MaxDepth_chr17', 'value': '156.09'},
#        {'key': 'MaxDepth_chr18', 'value': '161.58'},
#        {'key': 'MaxDepth_chr19', 'value': '152.31'},
#        {'key': 'MaxDepth_chr1', 'value': '156.6'},
#        {'key': 'MaxDepth_chr20', 'value': '152.1'},
# ...
#    'attributes': {'alignmentHeader': {'attributes': {},
#      'sequenceDiccionary': [{'sequenceName': 'chrM',
#        'sequenceLength': 16571,
#        'attributes': {}},
#       {'sequenceName': 'chr1', 'sequenceLength': 249250621, 'attributes': {}},
#       {'sequenceName': 'chr2', 'sequenceLength': 243199373, 'attributes': {}},
#       {'sequenceName': 'chr3', 'sequenceLength': 198022430, 'attributes': {}},
#       {'sequenceName': 'chr4', 'sequenceLength': 191154276, 'attributes': {}},
#       {'sequenceName': 'chr5', 'sequenceLength': 180915260, 'attributes': {}},
#       {'sequenceName': 'chr6', 'sequenceLength': 171115067, 'attributes': {}},
#       {'sequenceName': 'chr7', 'sequenceLength': 159138663, 'attributes': {}},
#       {'sequenceName': 'chr8', 'sequenceLength': 146364022, 'attributes': {}},
#       {'sequenceName': 'chr9', 'sequenceLength': 141213431, 'attributes': {}},
#       {'sequenceName': 'chr10', 'sequenceLength': 135534747, 'attributes': {}},
#       {'sequenceName': 'chr11', 'sequenceLength': 135006516, 'attributes': {}},
#       {'sequenceName': 'chr12', 'sequenceLength': 133851895, 'attributes': {}},
#       {'sequenceName': 'chr13', 'sequenceLength': 115169878, 'attributes': {}},
#       {'sequenceName': 'chr14', 'sequenceLength': 107349540, 'attributes': {}},
#       {'sequenceName': 'chr15', 'sequenceLength': 102531392, 'attributes': {}},
#       {'sequenceName': 'chr16', 'sequenceLength': 90354753, 'attributes': {}},
#       {'sequenceName': 'chr17', 'sequenceLength': 81195210, 'attributes': {}},
#       {'sequenceName': 'chr18', 'sequenceLength': 78077248, 'attributes': {}},
#       {'sequenceName': 'chr19', 'sequenceLength': 59128983, 'attributes': {}},
#       {'sequenceName': 'chr20', 'sequenceLength': 63025520, 'attributes': {}},
#       {'sequenceName': 'chr21', 'sequenceLength': 48129895, 'attributes': {}},
#       {'sequenceName': 'chr22', 'sequenceLength': 51304566, 'attributes': {}},
#       {'sequenceName': 'chrX', 'sequenceLength': 155270560, 'attributes': {}},
#       {'sequenceName': 'chrY', 'sequenceLength': 59373566, 'attributes': {}}],
#      'readGroups': [{'id': 'NA12878', 'attributes': {'SM': 'NA12878'}}],
#      'programRecords': [{'id': 'bwa',
#        'attributes': {'VN': '0.6.1-r104-tpx', 'PN': 'bwa'}}],
#      'comments': [],
#      'studyName': 'Platinum',
#      'origin': 'SAM'}}},
#   {'id': 'data:NA12878_S1.bam.bai',
#    'annotationSets': [],
#    'name': 'NA12878_S1.bam.bai',
#    'uuid': 'rOjotgFnAAMAAariF0UlZg',
#    'type': 'FILE',
#    'format': 'BAI',
#    'bioformat': 'ALIGNMENT',
#    'checksum': '',
#    'uri': 'file:///mnt/data/hgva/datasets/bams/NA12878_S1.bam.bai',
#    'path': 'data/NA12878_S1.bam.bai',
#    'release': 1,
#    'creationDate': '20181214133004',
#    'modificationDate': '20181214133004',
#    'description': '',
#    'status': {'name': 'READY', 'date': '20181214133004', 'message': ''},
#    'external': True,
#    'size': 8750352,
#    'experiment': {},
#    'samples': [],
#    'tags': [],
#    'job': {'startTime': 0,
#     'endTime': 0,
#     'visited': False,
#     'size': 0,
#     'release': 0},
#    'relatedFiles': [],
#    'index': {'jobId': 0, 'release': 0},
#    'stats': {},
#    'attributes': {}},
#   {'id': 'data:NA12878_S1.bam.coverage.bw',
#    'annotationSets': [],
#    'name': 'NA12878_S1.bam.coverage.bw',
#    'uuid': 'rOjpMgFnAAMAAcK2u51t4Q',
#    'type': 'FILE',
#    'format': 'BIGWIG',
#    'bioformat': 'COVERAGE',
#    'checksum': '',
#    'uri': 'file:///mnt/data/hgva/datasets/bams/NA12878_S1.bam.coverage.bw',
#    'path': 'data/NA12878_S1.bam.coverage.bw',
#    'release': 1,
#    'creationDate': '20181214133004',
#    'modificationDate': '20181214133004',
#    'description': '',
#    'status': {'name': 'READY', 'date': '20181214133004', 'message': ''},
#    'external': True,
#    'size': 307413923,
#    'experiment': {},
#    'samples': [],
#    'tags': [],
#    'job': {'startTime': 0,
#     'endTime': 0,
#     'visited': False,
#     'size': 0,
#     'release': 0},
#    'relatedFiles': [],
#    'index': {'jobId': 0, 'release': 0},
#    'stats': {},
#    'attributes': {}},
#   {'id': 'data:NA12879_S1.bam',
#    'annotationSets': [],
#    'name': 'NA12879_S1.bam',
#    'uuid': 'rOjpoQFnAAMAAY6izEvxGw',
#    'type': 'FILE',
#    'format': 'BAM',
#    'bioformat': 'ALIGNMENT',
#    'checksum': '',
#    'uri': 'file:///mnt/data/hgva/datasets/bams/NA12879_S1.bam',
#    'path': 'data/NA12879_S1.bam',
#    'release': 1,
#    'creationDate': '20181214133004',
#    'modificationDate': '20190122052441',
#    'description': '',
#    'status': {'name': 'READY', 'date': '20181214133004', 'message': ''},
#    'external': True,
#    'size': 125570264101,
#    'experiment': {},
#    'samples': [{'id': 'NA12879',
#      'uuid': '7Rrs-wFlAAQAAQMADI03VQ',
#      'source': 'platinum-genomes-vcf-NA12879_S1.genome.vcf.gz',
#      'individual': {'release': 0,
#       'version': 0,
#       'parentalConsanguinity': False},
#      'release': 1,
#      'version': 1,
#      'creationDate': '20180918143449',
#      'status': {'name': 'READY', 'date': '20180918143449', 'message': ''},
#      'description': '',
#      'type': '',
#      'somatic': False,
#      'phenotypes': [],
#      'stats': {},
#      'attributes': {}}],
#    'tags': [],
#    'job': {'startTime': 0,
#     'endTime': 0,
#     'visited': False,
#     'size': 0,
#     'release': 0},
#    'relatedFiles': [],
#    'index': {'jobId': 0, 'release': 0},
#    'stats': {'globalStats': '{"numMapped":42946,"numUnmapped":7054,"numPaired":25576,"numMappedFirst":22864,"numMappedSecond":20082,"NM":78353,"numHardC":0,"numSoftC":5790,"numIn":606,"numDel":187,"numPad":0,"numSkip":0,"accMappingQuality":2131165,"mappingQualityMap":{"48":2,"17":38,"50":4,"37":17225,"25":150,"60":24161,"29":1357,"15":9},"accInsert":7452528,"insertMap":{"66":1,"90":1,"102":8,"103":4,"104":2,"105":6,"107":6,"108":2,"109":2,"110":2,"111":2,"112":2,"113":2,"114":3,"115":6,"116":2,"119":4,"120":7,"121":6,"122":10,"123":10,"124":4,"126":6,"127":3,"128":6,"129":10,"130":6,"131":3,"132":14,"133":4,"134":10,"135":8,"136":10,"137":6,"138":5,"139":10,"140":12,"141":12,"142":6,"143":8,"144":8,"145":9,"146":4,"147":16,"148":15,"149":10,"150":11,"151":6,"152":4,"153":13,"154":12,"155":8,"156":17,"157":9,"158":13,"159":2,"160":14,"161":16,"162":18,"163":35,"164":17,"165":22,"166":27,"167":20,"168":27,"169":23,"170":25,"171":20,"172":9,"173":41,"174":25,"175":37,"176":20,"177":20,"178":32,"179":38,"180":26,"181":25,"182":23,"183":26,"184":26,"185":32,"186":36,"187":29,"188":52,"189":38,"190":27,"191":18,"192":40,"193":40,"194":45,"195":36,"196":43,"197":50,"198":41,"199":51,"200":50,"201":52,"202":46,"203":50,"204":57,"205":53,"206":79,"207":50,"208":65,"209":66,"210":57,"211":73,"212":57,"213":66,"214":68,"215":84,"216":63,"217":77,"218":71,"219":62,"220":83,"221":81,"222":81,"223":81,"224":90,"225":105,"226":93,"227":88,"228":91,"229":105,"230":102,"231":104,"232":113,"233":82,"234":129,"235":143,"236":131,"237":116,"238":133,"239":172,"240":104,"241":129,"242":147,"243":129,"244":124,"245":126,"246":127,"247":139,"248":141,"249":145,"250":178,"251":120,"252":147,"253":173,"254":125,"255":159,"256":161,"257":156,"258":185,"259":158,"260":155,"261":143,"262":184,"263":169,"264":170,"265":174,"266":153,"267":196,"268":165,"269":155,"270":212,"271":162,"272":149,"273":160,"274":194,"275":206,"276":185,"277":197,"278":162,"279":154,"280":162,"281":181,"282":185,"283":144,"284":186,"285":150,"286":182,"287":178,"288":160,"289":179,"290":196,"291":193,"292":143,"293":189,"294":187,"295":192,"296":157,"297":142,"298":187,"299":184,"300":160,"301":184,"302":156,"303":184,"304":191,"305":155,"306":185,"307":189,"308":178,"309":162,"310":154,"311":170,"312":172,"313":180,"314":157,"315":145,"316":122,"317":152,"318":156,"319":132,"320":142,"321":136,"322":136,"323":117,"324":121,"325":138,"326":106,"327":132,"328":111,"329":128,"330":130,"331":126,"332":130,"333":113,"334":118,"335":108,"336":102,"337":118,"338":107,"339":119,"340":105,"341":122,"342":78,"343":111,"344":99,"345":93,"346":87,"347":89,"348":82,"349":84,"350":75,"351":99,"352":89,"353":102,"354":70,"355":68,"356":91,"357":90,"358":69,"359":67,"360":83,"361":85,"362":72,"363":58,"364":77,"365":63,"366":59,"367":56,"368":67,"369":57,"370":64,"371":60,"372":67,"373":62,"374":70,"375":55,"376":48,"377":51,"378":53,"379":46,"380":40,"381":58,"382":41,"383":46,"384":49,"385":36,"386":40,"387":40,"388":41,"389":37,"390":47,"391":37,"392":34,"393":25,"394":37,"395":31,"396":37,"397":36,"398":16,"399":48,"400":38,"401":30,"402":28,"403":27,"404":28,"405":23,"406":27,"407":24,"408":30,"409":30,"410":34,"411":23,"412":26,"413":19,"414":30,"415":23,"416":19,"417":22,"418":20,"419":18,"420":11,"421":16,"422":25,"423":21,"424":20,"425":14,"426":20,"427":15,"428":13,"429":16,"430":14,"431":17,"432":17,"433":16,"434":10,"435":16,"436":12,"437":13,"438":12,"439":23,"440":9,"441":8,"442":8,"443":7,"444":8,"445":11,"446":9,"447":7,"448":12,"449":13,"450":10,"451":13,"452":10,"453":10,"454":2,"455":8,"456":9,"457":7,"458":10,"459":6,"460":10,"461":7,"462":12,"463":9,"464":12,"465":7,"466":7,"467":6,"468":6,"469":10,"470":3,"472":6,"473":6,"474":10,"475":4,"476":4,"477":5,"478":2,"479":3,"480":3,"481":2,"482":4,"483":2,"484":3,"485":5,"486":1,"487":4,"488":1,"489":2,"490":6,"491":4,"492":1,"493":5,"494":3,"495":4,"496":2,"497":3,"498":2,"499":2,"500":5,"501":2,"502":1,"504":4,"505":4,"506" ...
#    'attributes': {'alignmentHeader': {'attributes': {},
#      'sequenceDiccionary': [{'sequenceName': 'chrM',
#        'sequenceLength': 16571,
#        'attributes': {}},
#       {'sequenceName': 'chr1', 'sequenceLength': 249250621, 'attributes': {}},
#       {'sequenceName': 'chr2', 'sequenceLength': 243199373, 'attributes': {}},
#       {'sequenceName': 'chr3', 'sequenceLength': 198022430, 'attributes': {}},
#       {'sequenceName': 'chr4', 'sequenceLength': 191154276, 'attributes': {}},
#       {'sequenceName': 'chr5', 'sequenceLength': 180915260, 'attributes': {}},
#       {'sequenceName': 'chr6', 'sequenceLength': 171115067, 'attributes': {}},
#       {'sequenceName': 'chr7', 'sequenceLength': 159138663, 'attributes': {}},
#       {'sequenceName': 'chr8', 'sequenceLength': 146364022, 'attributes': {}},
#       {'sequenceName': 'chr9', 'sequenceLength': 141213431, 'attributes': {}},
#       {'sequenceName': 'chr10', 'sequenceLength': 135534747, 'attributes': {}},
#       {'sequenceName': 'chr11', 'sequenceLength': 135006516, 'attributes': {}},
#       {'sequenceName': 'chr12', 'sequenceLength': 133851895, 'attributes': {}},
#       {'sequenceName': 'chr13', 'sequenceLength': 115169878, 'attributes': {}},
#       {'sequenceName': 'chr14', 'sequenceLength': 107349540, 'attributes': {}},
#       {'sequenceName': 'chr15', 'sequenceLength': 102531392, 'attributes': {}},
#       {'sequenceName': 'chr16', 'sequenceLength': 90354753, 'attributes': {}},
#       {'sequenceName': 'chr17', 'sequenceLength': 81195210, 'attributes': {}},
#       {'sequenceName': 'chr18', 'sequenceLength': 78077248, 'attributes': {}},
#       {'sequenceName': 'chr19', 'sequenceLength': 59128983, 'attributes': {}},
#       {'sequenceName': 'chr20', 'sequenceLength': 63025520, 'attributes': {}},
#       {'sequenceName': 'chr21', 'sequenceLength': 48129895, 'attributes': {}},
#       {'sequenceName': 'chr22', 'sequenceLength': 51304566, 'attributes': {}},
#       {'sequenceName': 'chrX', 'sequenceLength': 155270560, 'attributes': {}},
#       {'sequenceName': 'chrY', 'sequenceLength': 59373566, 'attributes': {}}],
#      'readGroups': [{'id': 'NA12879', 'attributes': {'SM': 'NA12879'}}],
#      'programRecords': [{'id': 'bwa',
#        'attributes': {'VN': '0.6.1-r104-tpx', 'PN': 'bwa'}}],
#      'comments': [],
#      'studyName': 'Platinum',
#      'origin': 'SAM'}}},
#   {'id': 'data:NA12879_S1.bam.bai',
#    'annotationSets': [],
#    'name': 'NA12879_S1.bam.bai',
#    'uuid': 'rOjqVQFnAAMAAZ7XsP30GA',
#    'type': 'FILE',
#    'format': 'BAI',
#    'bioformat': 'ALIGNMENT',
#    'checksum': '',
#    'uri': 'file:///mnt/data/hgva/datasets/bams/NA12879_S1.bam.bai',
#    'path': 'data/NA12879_S1.bam.bai',
#    'release': 1,
#    'creationDate': '20181214133004',
#    'modificationDate': '20181214133004',
#    'description': '',
#    'status': {'name': 'READY', 'date': '20181214133004', 'message': ''},
#    'external': True,
#    'size': 8744304,
#    'experiment': {},
#    'samples': [],
#    'tags': [],
#    'job': {'startTime': 0,
#     'endTime': 0,
#     'visited': False,
#     'size': 0,
#     'release': 0},
#    'relatedFiles': [],
#    'index': {'jobId': 0, 'release': 0},
#    'stats': {},
#    'attributes': {}},
#   {'id': 'data:NA12879_S1.bam.coverage.bw',
#    'annotationSets': [],
#    'name': 'NA12879_S1.bam.coverage.bw',
#    'uuid': 'rOjq5gFnAAMAAbwN0F3AnA',
#    'type': 'FILE',
#    'format': 'BIGWIG',
#    'bioformat': 'COVERAGE',
#    'checksum': '',
#    'uri': 'file:///mnt/data/hgva/datasets/bams/NA12879_S1.bam.coverage.bw',
#    'path': 'data/NA12879_S1.bam.coverage.bw',
#    'release': 1,
#    'creationDate': '20181214133004',
#    'modificationDate': '20181214133004',
#    'description': '',
#    'status': {'name': 'READY', 'date': '20181214133004', 'message': ''},
#    'external': True,
#    'size': 308311099,
#    'experiment': {},
#    'samples': [],
#    'tags': [],
#    'job': {'startTime': 0,
#     'endTime': 0,
#     'visited': False,
#     'size': 0,
#     'release': 0},
#    'relatedFiles': [],
#    'index': {'jobId': 0, 'release': 0},
#    'stats': {},
#    'attributes': {}}]]

# %% [markdown]
# ## Working with Users

# %%
user_client = oc.users
print(dir(user_client))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_category', '_cfg', '_client_login_handler', '_delete', '_get', '_get_query_id_str', '_post', '_refresh_token_client', '_rest_retry', 'auto_refresh', 'configs', 'create', 'delete', 'filters', 'info', 'login', 'login_handler', 'logout', 'on_retry', 'projects', 'refresh_token', 'session_id', 'update', 'update_configs', 'update_filter', 'update_filters', 'update_password']

# %%
## getting user information
## [NOTE] User needs the quey_id string directly --> (user)
user_client.info(user)
# Out:
# [[{'id': 'cafetero',
#    'name': 'Juan Valdés',
#    'email': 'cafetero@cafe.rico.es',
#    'organization': '',
#    'account': {'type': 'full',
#     'creationDate': '20180918141732',
#     'expirationDate': '20190918141732',
#     'authOrigin': 'internal'},
#    'status': {'name': 'READY', 'date': '20180918141732', 'message': ''},
#    'lastModified': '20190221155441344',
#    'size': -1,
#    'quota': 200000,
#    'projects': [{'id': 'GRCH37',
#      'name': 'GRCH37',
#      'uuid': '7Q5e4QFlAAEAAQ7Nii5FVA',
#      'fqn': 'cafetero@GRCH37',
#      'creationDate': '20180918142106',
#      'description': '',
#      'organization': '',
#      'organism': {'scientificName': 'Homo Sapiens',
#       'commonName': 'grch37',
#       'taxonomyCode': 0,
#       'assembly': 'grch37'},
#      'currentRelease': 1,
#      'status': {'name': 'READY', 'date': '20180918142106', 'message': ''},
#      'size': 0,
#      'studies': [{'id': 'platinum',
#        'name': 'Platinum',
#        'uuid': '7REdkAFlAAIAAVnBP_uPGg',
#        'type': 'CASE_CONTROL',
#        'creationDate': '20180918142406',
#        'modificationDate': '20180918142406',
#        'description': '',
#        'status': {'name': 'READY', 'date': '20180918142406', 'message': ''},
#        'lastModified': '20180918142406',
#        'size': 0,
#        'cipher': 'none',
#        'fqn': 'cafetero@GRCH37:platinum',
#        'groups': [{'id': '@members',
#          'name': 'members',
#          'userIds': ['test2', 'test3', 'test4', 'test1', 'cafetero']},
#         {'id': '@admins', 'name': 'admins', 'userIds': []}],
#        'experiments': [],
#        'files': [],
#        'jobs': [],
#        'individuals': [],
#        'samples': [],
#        'datasets': [],
#        'cohorts': [],
#        'panels': [],
#        'permissionRules': {},
#        'uri': 'file:///mnt/data/opencga-test/sessions/users/cafetero/projects/1/2/',
#        'release': 1,
#        'dataStores': {},
#        'stats': {},
#        'attributes': {}},
#       {'id': 'GNOMAD_EXOMES',
#        'name': 'GenomAD Exomes',
#        'uuid': '7RFu4AFlAAIAAZSS4XjzBA',
#        'type': 'CASE_CONTROL',
#        'creationDate': '20180918142427',
#        'modificationDate': '20180918142427',
#        'description': '',
#        'status': {'name': 'READY', 'date': '20180918142427', 'message': ''},
#        'lastModified': '20180918142427',
#        'size': 0,
#        'cipher': 'none',
#        'fqn': 'cafetero@GRCH37:GNOMAD_EXOMES',
#        'groups': [{'id': '@members',
#          'name': 'members',
#          'userIds': ['test2', 'test4']},
#         {'id': '@admins', 'name': 'admins', 'userIds': []}],
#        'experiments': [],
#        'files': [],
#        'jobs': [],
#        'individuals': [],
#        'samples': [],
#        'datasets': [],
#        'cohorts': [],
#        'panels': [],
#        'permissionRules': {},
#        'uri': 'file:///mnt/data/opencga-test/sessions/users/cafetero/projects/1/4/',
#        'release': 1,
#        'dataStores': {},
#        'stats': {},
#        'attributes': {}}],
#      'dataStores': {},
#      'attributes': {}}],
#    'tools': [],
#    'configs': {'filters': [{'name': 'Indels',
#       'description': 'Fetch all INDEL variants',
#       'bioformat': 'VARIANT',
#       'query': {'studies': 'cafetero@GRCH37:platinum', 'type': 'INDEL'},
#       'options': {}}]},
#    'attributes': {}}]]

# %%
## Getting user projects
## [NOTE] Client specific methods have the query_id as a key:value (i.e (user=user_id)) 
user_client.projects(user=user)
# Out:
# [[{'id': 'GRCH37',
#    'name': 'GRCH37',
#    'uuid': '7Q5e4QFlAAEAAQ7Nii5FVA',
#    'fqn': 'cafetero@GRCH37',
#    'creationDate': '20180918142106',
#    'description': '',
#    'organization': '',
#    'organism': {'scientificName': 'Homo Sapiens',
#     'commonName': 'grch37',
#     'taxonomyCode': 0,
#     'assembly': 'grch37'},
#    'currentRelease': 1,
#    'status': {'name': 'READY', 'date': '20180918142106', 'message': ''},
#    'size': 0,
#    'studies': [{'id': 'platinum',
#      'name': 'Platinum',
#      'uuid': '7REdkAFlAAIAAVnBP_uPGg',
#      'type': 'CASE_CONTROL',
#      'creationDate': '20180918142406',
#      'modificationDate': '20180918142406',
#      'description': '',
#      'status': {'name': 'READY', 'date': '20180918142406', 'message': ''},
#      'lastModified': '20180918142406',
#      'size': 0,
#      'cipher': 'none',
#      'fqn': 'cafetero@GRCH37:platinum',
#      'groups': [{'id': '@members',
#        'name': 'members',
#        'userIds': ['test2', 'test3', 'test4', 'test1', 'cafetero']},
#       {'id': '@admins', 'name': 'admins', 'userIds': []}],
#      'experiments': [],
#      'files': [],
#      'jobs': [],
#      'individuals': [],
#      'samples': [],
#      'datasets': [],
#      'cohorts': [],
#      'panels': [],
#      'variableSets': [],
#      'permissionRules': {},
#      'uri': 'file:///mnt/data/opencga-test/sessions/users/cafetero/projects/1/2/',
#      'release': 1,
#      'dataStores': {},
#      'stats': {},
#      'attributes': {}},
#     {'id': 'GNOMAD_EXOMES',
#      'name': 'GenomAD Exomes',
#      'uuid': '7RFu4AFlAAIAAZSS4XjzBA',
#      'type': 'CASE_CONTROL',
#      'creationDate': '20180918142427',
#      'modificationDate': '20180918142427',
#      'description': '',
#      'status': {'name': 'READY', 'date': '20180918142427', 'message': ''},
#      'lastModified': '20180918142427',
#      'size': 0,
#      'cipher': 'none',
#      'fqn': 'cafetero@GRCH37:GNOMAD_EXOMES',
#      'groups': [{'id': '@members',
#        'name': 'members',
#        'userIds': ['test2', 'test4']},
#       {'id': '@admins', 'name': 'admins', 'userIds': []}],
#      'experiments': [],
#      'files': [],
#      'jobs': [],
#      'individuals': [],
#      'samples': [],
#      'datasets': [],
#      'cohorts': [],
#      'panels': [],
#      'variableSets': [],
#      'permissionRules': {},
#      'uri': 'file:///mnt/data/opencga-test/sessions/users/cafetero/projects/1/4/',
#      'release': 1,
#      'dataStores': {},
#      'stats': {},
#      'attributes': {}}],
#    'dataStores': {},
#    'attributes': {}}]]

# %%
## Getting user configurations
## [NOTE] Client specific methods have the query_id as a key:value (i.e (user=user_id)) 
user_client.configs(user=user)
# Out:
# [[{}]]

# %%
## Getting user filter configurations
## [NOTE] Client specific methods have the query_id as a key:value (i.e (user=user_id)) 
user_client.filters(user=user)
# Out:
# [[{'name': 'Indels',
#    'description': 'Fetch all INDEL variants',
#    'bioformat': 'VARIANT',
#    'query': {'studies': 'cafetero@GRCH37:platinum', 'type': 'INDEL'},
#    'options': {}}]]

# %% [markdown]
# ## Working with Projects

# %%
project_client = oc.projects
print(dir(oc.projects))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_category', '_cfg', '_client_login_handler', '_delete', '_get', '_get_query_id_str', '_post', '_refresh_token_client', '_rest_retry', 'auto_refresh', 'create', 'delete', 'increment_release', 'info', 'login_handler', 'on_retry', 'search', 'session_id', 'stats', 'studies', 'update']

# %%
## Getting all projects from logged in user
project_client.search()
# Out:
# [[{'id': 'GRCH37',
#    'name': 'GRCH37',
#    'uuid': '7Q5e4QFlAAEAAQ7Nii5FVA',
#    'fqn': 'cafetero@GRCH37',
#    'creationDate': '20180918142106',
#    'description': '',
#    'organization': '',
#    'organism': {'scientificName': 'Homo Sapiens',
#     'commonName': 'grch37',
#     'taxonomyCode': 0,
#     'assembly': 'grch37'},
#    'currentRelease': 1,
#    'status': {'name': 'READY', 'date': '20180918142106', 'message': ''},
#    'size': 0,
#    'studies': [{'id': 'platinum',
#      'name': 'Platinum',
#      'uuid': '7REdkAFlAAIAAVnBP_uPGg',
#      'type': 'CASE_CONTROL',
#      'creationDate': '20180918142406',
#      'modificationDate': '20180918142406',
#      'description': '',
#      'status': {'name': 'READY', 'date': '20180918142406', 'message': ''},
#      'lastModified': '20180918142406',
#      'size': 0,
#      'cipher': 'none',
#      'fqn': 'cafetero@GRCH37:platinum',
#      'groups': [{'id': '@members',
#        'name': 'members',
#        'userIds': ['test2', 'test3', 'test4', 'test1', 'cafetero']},
#       {'id': '@admins', 'name': 'admins', 'userIds': []}],
#      'experiments': [],
#      'files': [],
#      'jobs': [],
#      'individuals': [],
#      'samples': [],
#      'datasets': [],
#      'cohorts': [],
#      'panels': [],
#      'variableSets': [],
#      'permissionRules': {},
#      'uri': 'file:///mnt/data/opencga-test/sessions/users/cafetero/projects/1/2/',
#      'release': 1,
#      'dataStores': {},
#      'stats': {},
#      'attributes': {}},
#     {'id': 'GNOMAD_EXOMES',
#      'name': 'GenomAD Exomes',
#      'uuid': '7RFu4AFlAAIAAZSS4XjzBA',
#      'type': 'CASE_CONTROL',
#      'creationDate': '20180918142427',
#      'modificationDate': '20180918142427',
#      'description': '',
#      'status': {'name': 'READY', 'date': '20180918142427', 'message': ''},
#      'lastModified': '20180918142427',
#      'size': 0,
#      'cipher': 'none',
#      'fqn': 'cafetero@GRCH37:GNOMAD_EXOMES',
#      'groups': [{'id': '@members',
#        'name': 'members',
#        'userIds': ['test2', 'test4']},
#       {'id': '@admins', 'name': 'admins', 'userIds': []}],
#      'experiments': [],
#      'files': [],
#      'jobs': [],
#      'individuals': [],
#      'samples': [],
#      'datasets': [],
#      'cohorts': [],
#      'panels': [],
#      'variableSets': [],
#      'permissionRules': {},
#      'uri': 'file:///mnt/data/opencga-test/sessions/users/cafetero/projects/1/4/',
#      'release': 1,
#      'dataStores': {},
#      'stats': {},
#      'attributes': {}}],
#    'dataStores': {},
#    'attributes': {}}]]

# %%
## Getting information from a specific project
project_client.info('GRCH37')
# Out:
# [[{'id': 'GRCH37',
#    'name': 'GRCH37',
#    'uuid': '7Q5e4QFlAAEAAQ7Nii5FVA',
#    'fqn': 'cafetero@GRCH37',
#    'creationDate': '20180918142106',
#    'description': '',
#    'organization': '',
#    'organism': {'scientificName': 'Homo Sapiens',
#     'commonName': 'grch37',
#     'taxonomyCode': 0,
#     'assembly': 'grch37'},
#    'currentRelease': 1,
#    'status': {'name': 'READY', 'date': '20180918142106', 'message': ''},
#    'size': 0,
#    'studies': [{'id': 'platinum',
#      'name': 'Platinum',
#      'uuid': '7REdkAFlAAIAAVnBP_uPGg',
#      'type': 'CASE_CONTROL',
#      'creationDate': '20180918142406',
#      'modificationDate': '20180918142406',
#      'description': '',
#      'status': {'name': 'READY', 'date': '20180918142406', 'message': ''},
#      'lastModified': '20180918142406',
#      'size': 0,
#      'cipher': 'none',
#      'fqn': 'cafetero@GRCH37:platinum',
#      'groups': [{'id': '@members',
#        'name': 'members',
#        'userIds': ['test2', 'test3', 'test4', 'test1', 'cafetero']},
#       {'id': '@admins', 'name': 'admins', 'userIds': []}],
#      'experiments': [],
#      'files': [],
#      'jobs': [],
#      'individuals': [],
#      'samples': [],
#      'datasets': [],
#      'cohorts': [],
#      'panels': [],
#      'variableSets': [],
#      'permissionRules': {},
#      'uri': 'file:///mnt/data/opencga-test/sessions/users/cafetero/projects/1/2/',
#      'release': 1,
#      'dataStores': {},
#      'stats': {},
#      'attributes': {}},
#     {'id': 'GNOMAD_EXOMES',
#      'name': 'GenomAD Exomes',
#      'uuid': '7RFu4AFlAAIAAZSS4XjzBA',
#      'type': 'CASE_CONTROL',
#      'creationDate': '20180918142427',
#      'modificationDate': '20180918142427',
#      'description': '',
#      'status': {'name': 'READY', 'date': '20180918142427', 'message': ''},
#      'lastModified': '20180918142427',
#      'size': 0,
#      'cipher': 'none',
#      'fqn': 'cafetero@GRCH37:GNOMAD_EXOMES',
#      'groups': [{'id': '@members',
#        'name': 'members',
#        'userIds': ['test2', 'test4']},
#       {'id': '@admins', 'name': 'admins', 'userIds': []}],
#      'experiments': [],
#      'files': [],
#      'jobs': [],
#      'individuals': [],
#      'samples': [],
#      'datasets': [],
#      'cohorts': [],
#      'panels': [],
#      'variableSets': [],
#      'permissionRules': {},
#      'uri': 'file:///mnt/data/opencga-test/sessions/users/cafetero/projects/1/4/',
#      'release': 1,
#      'dataStores': {},
#      'stats': {},
#      'attributes': {}}],
#    'dataStores': {},
#    'attributes': {}}]]

# %%
## Fetching the studies from a project
project_client.studies('GRCH37')
# Out:
# [[{'id': 'platinum',
#    'name': 'Platinum',
#    'uuid': '7REdkAFlAAIAAVnBP_uPGg',
#    'type': 'CASE_CONTROL',
#    'creationDate': '20180918142406',
#    'modificationDate': '20180918142406',
#    'description': '',
#    'status': {'name': 'READY', 'date': '20180918142406', 'message': ''},
#    'lastModified': '20180918142406',
#    'size': 0,
#    'cipher': 'none',
#    'fqn': 'cafetero@GRCH37:platinum',
#    'groups': [{'id': '@members',
#      'name': 'members',
#      'userIds': ['test2', 'test3', 'test4', 'test1', 'cafetero']},
#     {'id': '@admins', 'name': 'admins', 'userIds': []}],
#    'experiments': [],
#    'files': [],
#    'jobs': [],
#    'individuals': [],
#    'samples': [],
#    'datasets': [],
#    'cohorts': [],
#    'panels': [],
#    'variableSets': [],
#    'permissionRules': {},
#    'uri': 'file:///mnt/data/opencga-test/sessions/users/cafetero/projects/1/2/',
#    'release': 1,
#    'dataStores': {},
#    'stats': {},
#    'attributes': {}},
#   {'id': 'GNOMAD_EXOMES',
#    'name': 'GenomAD Exomes',
#    'uuid': '7RFu4AFlAAIAAZSS4XjzBA',
#    'type': 'CASE_CONTROL',
#    'creationDate': '20180918142427',
#    'modificationDate': '20180918142427',
#    'description': '',
#    'status': {'name': 'READY', 'date': '20180918142427', 'message': ''},
#    'lastModified': '20180918142427',
#    'size': 0,
#    'cipher': 'none',
#    'fqn': 'cafetero@GRCH37:GNOMAD_EXOMES',
#    'groups': [{'id': '@members',
#      'name': 'members',
#      'userIds': ['test2', 'test4']},
#     {'id': '@admins', 'name': 'admins', 'userIds': []}],
#    'experiments': [],
#    'files': [],
#    'jobs': [],
#    'individuals': [],
#    'samples': [],
#    'datasets': [],
#    'cohorts': [],
#    'panels': [],
#    'variableSets': [],
#    'permissionRules': {},
#    'uri': 'file:///mnt/data/opencga-test/sessions/users/cafetero/projects/1/4/',
#    'release': 1,
#    'dataStores': {},
#    'stats': {},
#    'attributes': {}}]]

# %%
## Getting stats from a project --> It seems that the Solr service is not working!!!
project_client.stats('GRCH37')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-19-4c0a654dfb74> in <module>()
#       1 ## Getting stats from a project --> It seems that the Solr service is not working!!!
# ----> 2 project_client.stats('GRCH37')
#
# /DATA/DATA_docker/projects_software/opencb/opencga/opencga-fork_pyclient-mgviz_branch/opencga-client/src/main/python/pyOpenCGA/pyopencga/rest_clients/project_client.py in stats(self, project, **options)
#      54             e.g.: studies;type. For nested fields use >>, e.g.: studies>>biotype;type
#      55         """
# ---> 56         return self._get('stats', query_id=project, **options)
#      57
#      58     def studies(self, project, **options):
#
# /DATA/DATA_docker/projects_software/opencb/opencga/opencga-fork_pyclient-mgviz_branch/opencga-client/src/main/python/pyOpenCGA/pyopencga/rest_clients/_parent_rest_clients.py in _get(self, resource, query_id, subcategory, second_query_id, **options)
#      74     def _get(self, resource, query_id=None, subcategory=None, second_query_id=None, **options):
#      75         """Queries the REST service and returns the result"""
# ---> 76         return self._rest_retry('get', resource, query_id, subcategory, second_query_id, **options)
#      77
#      78     def _post(self, resource, data, query_id=None, subcategory=None, second_query_id=None, **options):
#
# /DATA/DATA_docker/projects_software/opencb/opencga/opencga-fork_pyclient-mgviz_branch/opencga-client/src/main/python/pyOpenCGA/pyopencga/rest_clients/_parent_rest_clients.py in _rest_retry(self, method, resource, query_id, subcategory, second_query_id, data, dont_retry, **options)
#      66             exec_retry, self._cfg.max_attempts, self._cfg.min_retry_secs, self._cfg.max_retry_secs,
#      67             login_handler=self._client_login_handler if self.login_handler else None,
# ---> 68             on_retry=notify_retry, dont_retry=dont_retry)
#      69
#      70         if self.auto_refresh:
#
# /DATA/DATA_docker/projects_software/opencb/opencga/opencga-fork_pyclient-mgviz_branch/opencga-client/src/main/python/pyOpenCGA/pyopencga/retry.py in retry(func, max_attempts, initial_retry_seconds, max_retry_seconds, login_handler, on_retry, dont_retry)
#      34     while True:
#      35         try:
# ---> 36             return func()
#      37         except OpenCgaInvalidToken as e:
#      38
#
# /DATA/DATA_docker/projects_software/opencb/opencga/opencga-fork_pyclient-mgviz_branch/opencga-client/src/main/python/pyOpenCGA/pyopencga/rest_clients/_parent_rest_clients.py in exec_retry()
#      52                            resource=resource,
#      53                            data=data,
# ---> 54                            options=options)
#      55
#      56         def notify_retry(exc_type, exc_val, exc_tb):
#
# /DATA/DATA_docker/projects_software/opencb/opencga/opencga-fork_pyclient-mgviz_branch/opencga-client/src/main/python/pyOpenCGA/pyopencga/commons.py in execute(host, version, sid, category, resource, method, subcategory, query_id, second_query_id, data, **options)
#     289         response = _fetch(host=host, version=version, sid=sid, category=category, subcategory=subcategory,
#     290                           resource=resource, method=method, data=data,
# --> 291                           query_id=query_id, second_query_id=second_query_id, **options)
#     292         return response
#     293     else:
#
# /DATA/DATA_docker/projects_software/opencb/opencga/opencga-fork_pyclient-mgviz_branch/opencga-client/src/main/python/pyOpenCGA/pyopencga/commons.py in _fetch(host, version, sid, category, resource, method, subcategory, query_id, second_query_id, data, **options)
#     209
#     210         elif r.status_code != 200:
# --> 211             raise Exception(r.content)
#     212
#     213         try:
#
# Exception: b'{"apiVersion":"v1","time":136,"warning":"","error":"Solr server is not alive","queryOptions":{"metadata":true,"skipCount":true,"skip":0,"limit":1000},"response":[{"id":"","dbTime":-1,"numResults":-1,"numTotalResults":-1,"warningMsg":"Future errors will ONLY be shown in the QueryResponse body","errorMsg":"DEPRECATED: org.apache.solr.common.SolrException: Solr server is not alive","resultType":"","result":[]}]}'
